# %%
from __future__ import print_function
import numpy as np
import random
import sys

# %%
text = open('./shakespeare_final.txt', 'rt', encoding='UTF8').read().lower()

# %%
characters = sorted(list(set(text)))

# %%
print('corpus length:', len(text))
print('total chars:', len(characters))
# Out:
# corpus length: 196788
# total chars: 63

# %%
char2indices = dict((c, i) for i, c in enumerate(characters))
indices2char = dict((i, c) for i, c in enumerate(characters))

# %%
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))
# Out:
# nb sequences: 65583

# %%
# 인덱스를 벡터화된 형태로 변환
X = np.zeros((len(sentences), maxlen, len(characters)), dtype=np.bool)
y = np.zeros((len(sentences), len(characters)), dtype=np.bool)

for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        X[i, t, char2indices[char]] = 1
    y[i, char2indices[next_chars[i]]] = 1

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM,Activation,Dropout
from tensorflow.keras.optimizers import RMSprop

# %%
# 모델 구축
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(characters))))

model.add(Dense(len(characters)))

model.add(Activation('softmax'))
model.compile(loss='categorical_crossentropy', optimizer=RMSprop(lr=0.01))

print (model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 128)               98304
# _________________________________________________________________
# dense_1 (Dense)              (None, 63)                8127
# _________________________________________________________________
# activation_1 (Activation)    (None, 63)                0
# =================================================================
# Total params: 106,431
# Trainable params: 106,431
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# 예측을 인덱스로 변환하는 함수
def pred_indices(preds, metric=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / metric
    exp_preds = np.exp(preds)
    preds = exp_preds/np.sum(exp_preds)
    probs = np.random.multinomial(1, preds, 1)
    return np.argmax(probs)

# %%
# 모델 학습 및 평가
for iteration in range(1, 30):
    print('-' * 40)
    print('Iteration', iteration)
    model.fit(X, y,batch_size=128,epochs=1)

    start_index = random.randint(0, len(text) - maxlen - 1)

    for diversity in [0.2, 0.7,1.2]:

        print('\n----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x = np.zeros((1, maxlen, len(characters)))
            for t, char in enumerate(sentence):
                x[0, t, char2indices[char]] = 1.

            preds = model.predict(x, verbose=0)[0]
            next_index = pred_indices(preds, diversity)
            pred_char = indices2char[next_index]

            generated += pred_char
            sentence = sentence[1:] + pred_char

            sys.stdout.write(pred_char)
            sys.stdout.flush()
        print("\n하나의 조합 완료\n")
# Out:
# ----------------------------------------
# Iteration 1
# Epoch 1/1
# 65583/65583 [==============================] - 64s 973us/step - loss: 2.2736
#
# ----- diversity: 0.2
# ----- Generating with seed: "u!
#
# polonius. what treasure had he, my l"
# u!
#
# polonius. what treasure had he, my lord.
#
# king. the prome be the player.
#
# king. what he be the plown.
#
# king. what he sent the place be the prown the parte of the prown the bert.
#
# king. the prome the place the prome the prome the gent the plain the place the prome the prown the place the reart his and from the prownet.
#
# king. what in the place the place my lord.
#
# king. the with fith ser the fath with the bert, be whe promone.
#
# king.
# 하나의 조합 완료
#
#
# ----- diversity: 0.7
# ----- Generating with seed: "u!
#
# polonius. what treasure had he, my l"
# u!
#
# polonius. what treasure had he, my lood._]
#
# glaent; for wath wass. my lowa.
#
#  [_nowp, the port.
#
# flien..
#
# king. aspae his loct.
#
# frient._]
#
# spelliag._]
#
# faclet. whate, strembetot.
#
# hermain.
#
# gurterchrmesturcbuting sit not in bay, made in they stor
#
# vece wath referd!
#
# butents, rexkeng._]
#
# haw ther] as prownd, the will by dourd fis, fang.
#
# comsten._]
#
# known the plapecket._]
#
#
# non the rom, dhe with pall comnt, re, and well with of the
# 하나의 조합 완료
#
#
# ----- diversity: 1.2
# ----- Generating with seed: "u!
#
# polonius. what treasure had he, my l"
# u!
#
# polonius. what treasure had he, my letougo vene_gsedben,  fla?
#
# ableent._]
#
# kang. gund.zby: he save, bo.gh w]ith hi.
#
# purceinerraling._]  stiplbid; nop, lithat. o. wkl uspenthang. witn sle by bidsith
# ofermy._]]
# bld gevonb si  feve bek inm.
#
# a_,
# think [_geingxang- this
# dibinbgew]_]
#
# gziegitingod
# fk wat, eaes, nomery, unertr, no kasi’trg doing1, unclraxg.ud,’d lewssilr,—cnty, the frivied?
#
# king., him set’qur souf ?_]eou villy.— glera
# 하나의 조합 완료
#
# ----------------------------------------
# Iteration 2
# Epoch 1/1
# 65583/65583 [==============================] - 65s 996us/step - loss: 1.8268
#
# ----- diversity: 0.2
# ----- Generating with seed: "ikes it not, perdie. come,
# some music.
#
# "
# ikes it not, perdie. come,
# some music.
#
# hamlet. the player the came the king the reas the man the prayer the prome the reat the the firsing and the king the player and the player the player the player the king of the player the hath speak of the prayer.
#
# hamlet. i an the player the player of the king and the kings and sir, what shall the player this that the player the player the player in the the with the partion the project gutenberg
# 하나의 조합 완료
#
#
# ----- diversity: 0.7
# ----- Generating with seed: "ikes it not, perdie. come,
# some music.
#
# "
# ikes it not, perdie. come,
# some music.
#
# hamlet. the hamlet have
# serie, it was with any the rigurian him un te spring allows and to he what reburnights a this where of a your my litth me to farn such a like the purpadis as it hamlet.
#
# hamlet. ust him gray come, when that the rigit of emort this see, heartad.
#
# ophelia. in the ear. and thiscticl.—
# for a houds of witing in is nor where while the charseds. the king; that the spay fave of the
# 하나의 조합 완료
#
#
# ----- diversity: 1.2
# ----- Generating with seed: "ikes it not, perdie. come,
# some music.
#
# "
# ikes it not, perdie. come,
# some music.
#
# maronians?
#
# parsaus owreach, who entiged your came unsequread
# cope wituf any that
# thig.;
# thend allow gronnice. work.. but fy the daf.
#
# hamlet. lood,
# ead, it wher wise
# hive kntwenges,.
#
# hamlet. i oy i
# primich._]
#
# burca:lu. anourgh. a’ss
# vomany pyiruch’d did you rustian’s up cam-ver it kion do.—. whan sims, that ose plais any, than that from th?er anfer your unpurp ave
# grins. to  tell.
#
# hamlet. ghil
# 하나의 조합 완료
#
# ----------------------------------------
# Iteration 3
# Epoch 1/1
# 65583/65583 [==============================] - 63s 960us/step - loss: 1.6722
#
# ----- diversity: 0.2
# ----- Generating with seed: "ercial redistribution.
#
# start: full lice"
# ercial redistribution.
#
# start: full lice and the that is may that that that will the that is mark the castion of this the for the castion to the foundate to the the fell the castle the comming to the truck of this as father the father of this for the castion of this the father of the castion of the comple the father and the that is see the state of the castion of the father and the castion of the senter and the castions to the casted th
# 하나의 조합 완료
#
#
# ----- diversity: 0.7
# ----- Generating with seed: "ercial redistribution.
#
# start: full lice"
# ercial redistribution.
#
# start: full lice in me
# to you trome to you bread to pricats and firsted of
# hamlet. and that of far ows of this word come to it to my lord.
#
# hamlet. so he the frains, you ad of the tall this trecurieds have take the rear that will it to he do proteed the shall one in feether perpate of him.
#
# hamlet. set?
#
# queen. to hamlet, my lord.
#
# hamlet. it agial to purters here as it it ancune—take bardations in the dead and t
# 하나의 조합 완료
#
#
# ----- diversity: 1.2
# ----- Generating with seed: "ercial redistribution.
#
# start: full lice"
# ercial redistribution.
#
# start: full licep? that ormaluc’d the ecictits arate.
# playere; faley aphstquara
# lokperrus you to it part i
# priveste metwhat — as give beong opar
# offen. if, steaten culrh! wood arntireyquight ste heaven, my lind atcere)ty come, eceing this day eget: aggive ser
# stannenas. he pastment
# hawnelly sweec
# earstas.
#
# king. have a since.
# dobour wicce,ty for , lese?
#
# king. will pertund to in’s sauredfbead. for fastrens; thou
# 하나의 조합 완료
#
# ----------------------------------------
# Iteration 4
# Epoch 1/1
# 65583/65583 [==============================] - 59s 900us/step - loss: 1.5835
#
# ----- diversity: 0.2
# ----- Generating with seed: "r.
#
# captain. god b’ wi’ you, sir.
#
#  [_ex"
# r.
#
# captain. god b’ wi’ you, sir.
#
#  [_exeunt and good metthe the castle.
#
#  [_exeunt and good fer my lord, the castle.
#
# hamlet. the prosest of and a man and where his causes and me and the the makes my sees. the players of his countast the players the world in the players he we more in the castle.
#
# hamlet. the sent is makes the castle.
#
# hamlet. the castle.
#
# hamlet. ay, my lord, what i have me not the countions in the play the players the
# 하나의 조합 완료
#
#
# ----- diversity: 0.7
# ----- Generating with seed: "r.
#
# captain. god b’ wi’ you, sir.
#
#  [_ex"
# r.
#
# captain. god b’ wi’ you, sir.
#
#  [_exeunt fore. me
# ay a commstit as uping as a play a monert?
#
# horatio.
# hamlet.
#
# hamlet. his so let his at clowest that he could he have gentleman. now poose a mies fir ord have mad inder, seak of on copy immends showest for the castly the fellow liver he whill wes the will, my lord, whereing parthy.
#
# hamlet. to he what, he the canthing! the sfains in project gutenberg-tm works the canponseserhcoratio
# 하나의 조합 완료
#
#
# ----- diversity: 1.2
# ----- Generating with seed: "r.
#
# captain. god b’ wi’ you, sir.
#
#  [_ex"
# r.
#
# captain. god b’ wi’ you, sir.
#
#  [_exit o
# weel wher.ef potgntsww, her hum hat must but shall low trande. his upstablemn
# posuson as this, liefls
#  with longes pand done-disnclown ceat in’s, modest to ank my licets. conaciogish ot, and not we drigh the
# arcedss wher?i sete! his
# irintly.r
# had wasusings, and heven whereis, a
# throm mirty with come, hir which laelit of my greem he compake you bld ter dead loenth of capematis
# out the
# .
# cown
# 하나의 조합 완료
#
# ----------------------------------------
# Iteration 5
# Epoch 1/1
# 65583/65583 [==============================] - 70s 1ms/step - loss: 1.5126
#
# ----- diversity: 0.2
# ----- Generating with seed: "s of this agreement by keeping this work"
# s of this agreement by keeping this work of the book the heart as the pose of the project gutenberg-tm electronic works and be that work of the castle.
#
# hamlet. i how the consert to the king, and lord and that that stand in the track of the work of the project gutenberg-tm electronic works and that is man and to the consert to see that we most that we most the project gutenberg-tm electronic works and that me in the castle.
#
# hamlet. i w
# 하나의 조합 완료
#
#
# ----- diversity: 0.7
# ----- Generating with seed: "s of this agreement by keeping this work"
# s of this agreement by keeping this work of an at laes in that deven to but what should dear and
# his
# first to speak lord play mose of her whily and with out.
#
# ophelia. in a heart my lord.
#
# hamlet. then my lord, my lord.
#
# hamlet. why, flom th’eost than this mepions; that was heart a fort
# of unat to a king of eyiterad as nothelument.
#
# horatio. sir, what in my lord, in my bear good should and his wores good believaw that i well that eting
# 하나의 조합 완료
#
#
# ----- diversity: 1.2
# ----- Generating with seed: "s of this agreement by keeping this work"
# s of this agreement by keeping this work’dor rut.
#
# olanio. in a king. thus.
#
# horat itle thes o, that majesty; whatsenre mede done me double hath he that’s noud.
#
# uslici egpon. sreatip purbaly the posofcust,ul offect why
# cranomedy, fellow
#  thoughts are take agate you. my lord ho
# ruckous god! a king mure
# quild laedi’glaveresermenty largs to work seover no  nose blook, ase rema’s cloade, to not let are shall tanncriv
# it, loompprifon on
# my
# 하나의 조합 완료
#
# ----------------------------------------
# Iteration 6
# Epoch 1/1
# 65583/65583 [==============================] - 131s 2ms/step - loss: 1.4580
#
# ----- diversity: 0.2
# ----- Generating with seed: "r your
# well-took labour. go to your rest"
# r your
# well-took labour. go to your resting to the project gutenberg to the castle.
#
#  [_exeunt room it was a sleaser and states and could and mark and the reath of his life the count the project gutenberg to the count the project gutenberg to the project gutenberg to the countance of the project gutenberg to the countance of his countrituse, and let the world so fortune of the hand of the work of the bast to the states and states of the
# 하나의 조합 완료
#
#
# ----- diversity: 0.7
# ----- Generating with seed: "r your
# well-took labour. go to your rest"
# r your
# well-took labour. go to your restrus and brane are there of the tippovens,
# my lord. i have his levents of toness to heaven you
# than the castle.
#
#  [_exents and so queen and him. effenserful and verused it his away.
#
# rosencrantz engral wire jother of way is a pote; and bedich a motter out hamlet, makes it a thought with the world leathes, in their  the hither thate we sipe sorriggres you
# leck of the hall gond arms, lew.
#
#  [_exit._]
# 하나의 조합 완료
#
#
# ----- diversity: 1.2
# ----- Generating with seed: "r your
# well-took labour. go to your rest"
# r your
# well-took labour. go to your restlemor, tend tell. we it of pajes theme verykeme
# modividial,
# we know magiever
# attenecquelcion
# rauch letter heer.
#
# hamlet. nop ther.’ death dreat’d thought, but ih , suirh’d meets; but yougethe.
#
# king. with i, h, i a
# aspaciif.; and
#
# king. ay speaghts hiv away.
#
# martellcon o, theprake exor with lity liey give?
#
# daernes. you warol’r ever
# copmetying do though
# a rit eletrheblemtion; it is so sthank wher
# 하나의 조합 완료
#
# ----------------------------------------
# Iteration 7
# Epoch 1/1
#  6912/65583 [==>...........................] - ETA: 1:48 - loss: 1.3466- ETA: 1:53 - loss: 1.34 - ETA
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-e919e978e8f7> in <module>
#       3     print('-' * 40)
#       4     print('Iteration', iteration)
# ----> 5     model.fit(X, y,batch_size=128,epochs=1)
#       6
#       7     start_index = random.randint(0, len(text) - maxlen - 1)
#
# ~\anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1225
#    1226         # Delegate logic to `fit_loop`.
# -> 1227         return training_arrays.fit_loop(self, fit_function, fit_inputs,
#    1228                                         out_labels=out_labels,
#    1229                                         batch_size=batch_size,
#
# ~\anaconda3\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     194                     ins_batch[i] = ins_batch[i].toarray()
#     195
# --> 196                 outs = fit_function(ins_batch)
#     197                 outs = to_list(outs)
#     198                 for l, o in zip(out_labels, outs):
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\backend.py in __call__(self, inputs)
#    3790         value = math_ops.cast(value, tensor.dtype)
#    3791       converted_inputs.append(value)
# -> 3792     outputs = self._graph_fn(*converted_inputs)
#    3793
#    3794     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    1603       TypeError: For invalid positional/keyword argument combinations.
#    1604     """
# -> 1605     return self._call_impl(args, kwargs)
#    1606
#    1607   def _call_impl(self, args, kwargs, cancellation_manager=None):
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _call_impl(self, args, kwargs, cancellation_manager)
#    1643       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#    1644           list(kwargs.keys()), list(self._arg_keywords)))
# -> 1645     return self._call_flat(args, self.captured_inputs, cancellation_manager)
#    1646
#    1647   def _filtered_call(self, args, kwargs):
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1743         and executing_eagerly):
#    1744       # No tape is watching; skip to running the function.
# -> 1745       return self._build_call_outputs(self._inference_function.call(
#    1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     591       with _InterpolateFunctionError(self):
#     592         if cancellation_manager is None:
# --> 593           outputs = execute.execute(
#     594               str(self.signature.name),
#     595               num_outputs=self._num_outputs,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:
